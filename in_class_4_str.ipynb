# %%
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.ticker as mtickimport numpy as np
import pandas as pd
import seaborn as sbsb.set_theme()

# %%
DEFAULT_START = dt.date.isoformat(dt.date.today() - dt.timedelta(365))
DEFAULT_END = dt.date.isoformat(dt.date.today())

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show yfinance
# Out:
# Name: yfinance
# Version: 0.2.52
# Summary: Download market data from Yahoo! Finance API
# Home-page: https://github.com/ranaroussi/yfinance
# Author: Ran Aroussi
# Author-email: ran@aroussi.com
# License: Apache
# Location: /opt/anaconda3/lib/python3.12/site-packages
# Requires: beautifulsoup4, frozendict, html5lib, lxml, multitasking, numpy, pandas, peewee, platformdirs, pytz, requests
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
data = yf.download("NVDA", start="2025-02-01", end="2025-02-24")
print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NVDA']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# Empty DataFrame
# Columns: [(Adj Close, NVDA), (Close, NVDA), (High, NVDA), (Low, NVDA), (Open, NVDA), (Volume, NVDA)]
# Index: []

# %% [markdown]
# Could not download Yahoo finance data due to Yahoo's limitations. Python generates error message: "YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')" Skipped step below by downloading Yahoo finance data directly from site and importing via pandas.

# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/christinadeperro/Desktop/OIM7502/OIM7502_SP25/data/Yahoo Finance Data NIVIDA.xlsx')
print(df)
# Out:
#           Date    Open    High     Low  Close   Adj Close        Volume
# 0   2025-02-24  136.76  138.59  130.61  133.82      133.82  161921615.0
# 1   2025-02-21  140.04  141.46  134.03  134.43      134.43  227352400.0
# 2   2025-02-20  140.03  140.66  136.79  140.11      140.11  143903600.0
# 3   2025-02-19  139.51  141.36  137.22  139.23      139.23  167536000.0
# 4   2025-02-18  141.27  143.44  137.93  139.40      139.40  219176600.0
# ..         ...     ...     ...     ...     ...         ...          ...
# 250 2024-03-01      80   82.30   79.43   82.28       82.26  479135000.0
# 251 2024-02-29   79.09   79.99   78.35   79.11       79.09  507289000.0
# 252 2024-02-28   77.62   78.93   77.13   77.66       77.64  393110000.0
# 253 2024-02-27   79.38   79.48   77.16   78.70       78.68  391705000.0
# 254 2024-02-26    79.7   80.65   78.50   79.09       79.07  503973000.0
#
# [255 rows x 7 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index ('Date')
print(df)
print(df.index)
# Out:
#               Open    High     Low  Close   Adj Close        Volume
# Date
# 2025-02-24  136.76  138.59  130.61  133.82      133.82  161921615.0
# 2025-02-21  140.04  141.46  134.03  134.43      134.43  227352400.0
# 2025-02-20  140.03  140.66  136.79  140.11      140.11  143903600.0
# 2025-02-19  139.51  141.36  137.22  139.23      139.23  167536000.0
# 2025-02-18  141.27  143.44  137.93  139.40      139.40  219176600.0
# ...            ...     ...     ...     ...         ...          ...
# 2024-03-01      80   82.30   79.43   82.28       82.26  479135000.0
# 2024-02-29   79.09   79.99   78.35   79.11       79.09  507289000.0
# 2024-02-28   77.62   78.93   77.13   77.66       77.64  393110000.0
# 2024-02-27   79.38   79.48   77.16   78.70       78.68  391705000.0
# 2024-02-26    79.7   80.65   78.50   79.09       79.07  503973000.0
#
# [255 rows x 6 columns]
# DatetimeIndex(['2025-02-24', '2025-02-21', '2025-02-20', '2025-02-19',
# ...

# %%
class Stock:
    def __init__(self, symbol, start=DEFAULT_START, end=DEFAULT_END):
        self.symbol = symbol
        self.start = start
        self.end = end
        self.data = self.get_data()

# %%
    def get_data (self): 
  """method that downloads data and stores in a DataFrame
           uncomment the code below wich should be the final two lines 
           of your method"""
    self.calc_returns(data)
    return data
pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[133], line 5
#       1 def get_data (self, start_date):
#       2   """method that downloads data and stores in a DataFrame
#       3        uncomment the code below wich should be the final two lines
#       4        of your method"""
# ----> 5 self.calc_returns(data)
#       6 return data
#       7 pass
#
# NameError: name 'self' is not defined

# %% [markdown]
# Skipped step as I could not retrieve data from Yfinance directly.

# %%
import pandas as pd

df = pd.read_excel('/Users/christinadeperro/Desktop/OIM7502/OIM7502_SP25/data/Yahoo Finance Data NIVIDA.xlsx')

def calc_returns(self, df):  
    df['change_col'] = df['Adj Close'].diff()
    df['instant_return'] = np.log([closing_price]).diff().round(4)
    
pass
print(df)
# Out:
#           Date    Open    High     Low  Close   Adj Close        Volume
# 0   2025-02-24  136.76  138.59  130.61  133.82      133.82  161921615.0
# 1   2025-02-21  140.04  141.46  134.03  134.43      134.43  227352400.0
# 2   2025-02-20  140.03  140.66  136.79  140.11      140.11  143903600.0
# 3   2025-02-19  139.51  141.36  137.22  139.23      139.23  167536000.0
# 4   2025-02-18  141.27  143.44  137.93  139.40      139.40  219176600.0
# ..         ...     ...     ...     ...     ...         ...          ...
# 250 2024-03-01      80   82.30   79.43   82.28       82.26  479135000.0
# 251 2024-02-29   79.09   79.99   78.35   79.11       79.09  507289000.0
# 252 2024-02-28   77.62   78.93   77.13   77.66       77.64  393110000.0
# 253 2024-02-27   79.38   79.48   77.16   78.70       78.68  391705000.0
# 254 2024-02-26    79.7   80.65   78.50   79.09       79.07  503973000.0
#
# [255 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

df = pd.read_excel('/Users/christinadeperro/Desktop/OIM7502/OIM7502_SP25/data/Yahoo Finance Data NIVIDA.xlsx')

def calc_returns(self, df):  
    df['change_col'] = df['Adj Close'].diff()
    df['instant_return'] = np.log([closing_price]).diff().round(4)
    
def plot_return_dist(self):
    fig, ax = plt.subplots()
    ax.hist(np.random.rand(100), bins=10, orientation="horizontal")

for tick in ax.get_xticklabels():
    tick.set_rotation(45)
    
pass
df.hist()  
plt.show()

# %%
import matplotlib.pyplot as plt

df = pd.read_excel('/Users/christinadeperro/Desktop/OIM7502/OIM7502_SP25/data/Yahoo Finance Data NIVIDA.xlsx')

def plot_performance(self):
    plt.xlabel('change_col')
    plt.ylabel('Date')
    """method that plots stock object performance as percent """

df.plot(kind='line', y='Date', figsize=(10, 6))
plt.title('Instant Return')
plt.xlabel('change_col')
plt.ylabel('Date')
plt.grid(True)
    

pass
plt.show()

# %%
def main():
    stock_symbol = input(NVDA)
    test = Stock(symbol=[stock_symbol])
    print(test.data)
    test.plot_performance()
    test.plot_return_dist()

# %%
if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[427], line 2
#       1 if __name__ == '__main__':
# ----> 2     main()
#
# Cell In[425], line 2, in main()
#       1 def main():
# ----> 2     stock_symbol = input(NVDA)
#       3     test = Stock(symbol=[stock_symbol])
#       4     print(test.data)
#
# NameError: name 'NVDA' is not defined
